# %%
pip install tensorflow==2.18.0
# Out:
# ...
#   Using cached tensorflow-2.18.0-cp311-cp311-win_amd64.whl.metadata (3.3 kB)
# ...
#   Using cached tensorflow_intel-2.18.0-cp311-cp311-win_amd64.whl.metadata (4.9 kB)
# ...
#   Using cached tensorboard-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached keras-3.12.0-py3-none-any.whl.metadata (5.9 kB)
# ...
# Using cached tensorflow-2.18.0-cp311-cp311-win_amd64.whl (7.5 kB)
# Using cached tensorflow_intel-2.18.0-cp311-cp311-win_amd64.whl (390.2 MB)
# ...
#    ---------------------------------------- 0.0/15.9 MB ? eta -:--:--
#    --- ------------------------------------ 1.3/15.9 MB 8.4 MB/s eta 0:00:02
#    ------- -------------------------------- 3.1/15.9 MB 8.8 MB/s eta 0:00:02
#    ------------- -------------------------- 5.5/15.9 MB 9.3 MB/s eta 0:00:02
#    -------------------- ------------------- 8.1/15.9 MB 10.1 MB/s eta 0:00:01
#    --------------------------- ------------ 11.0/15.9 MB 10.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.2/15.9 MB 11.5 MB/s eta 0:00:01
# ...

# %%
import os
from tensorflow.keras.models import load_model

MODEL_TEST_PATH = os.path.abspath('models')
model_resnet50 = load_model(os.path.join(MODEL_TEST_PATH, 'ResNet50_phase2_best.h5'), compile=False)
model_resnet50.save(os.path.join(MODEL_TEST_PATH, 'ResNet50_phase2_best.keras'))

model_efficientnetb7 = load_model(os.path.join(MODEL_TEST_PATH, 'EfficientNetB7_phase2_best.h5'), compile=False)
model_efficientnetb7.save(os.path.join(MODEL_TEST_PATH, 'EfficientNetB7_phase2_best.keras'))

model_resnet50 = load_model(os.path.join(MODEL_TEST_PATH, 'ResNet50_final.h5'), compile=False)
model_resnet50.save(os.path.join(MODEL_TEST_PATH, 'ResNet50_final.keras'))
  
model_efficientnetb7 = load_model(os.path.join(MODEL_TEST_PATH, 'EfficientNetB7_final.h5'), compile=False)
model_efficientnetb7.save(os.path.join(MODEL_TEST_PATH, 'EfficientNetB7_final.keras'))
